# %%
import pandas as pd

data = pd.read_csv("dataset/dataset-final.csv")
data.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.350088         0.088757  0.130228  0.002827
# 1          0.340914         0.094980  0.095948  0.002373
# 2          0.363637         0.085275  0.175570  0.002746
# 3          0.404785         0.093999  0.141093  0.006346
# 4          0.308526         0.087841  0.091529  0.002303
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1784.165850            129774.0645              2002.449060
# 1             1530.176679            375850.0736              2039.036516
# 2             1552.811865            156467.6434              1747.702312
# 3             1070.106615            184355.9424              1596.412872
# 4             1835.004266            343399.9393              1748.172116
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_mean  \
# 0             85882.76132   3805.839606  9.015054e+05  ...     0.752740
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
plt.style.use('seaborn')
 
# %matplotlib inline
# Out:
# C:\Users\Jaymar Cezar\AppData\Local\Temp\ipykernel_5348\3073862703.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 57 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   chroma_stft_mean         1000 non-null   float64
#  1   chroma_stft_var          1000 non-null   float64
#  2   rms_mean                 1000 non-null   float64
#  3   rms_var                  1000 non-null   float64
#  4   spectral_centroid_mean   1000 non-null   float64
#  5   spectral_centroid_var    1000 non-null   float64
#  6   spectral_bandwidth_mean  1000 non-null   float64
#  7   spectral_bandwidth_var   1000 non-null   float64
#  8   rolloff_mean             1000 non-null   float64
#  9   rolloff_var              1000 non-null   float64
#  10  zero_crossing_rate_mean  1000 non-null   float64
#  11  zero_crossing_rate_var   1000 non-null   float64
#  12  harmony_mean             1000 non-null   float64
# ...

# %%
# Remove duplicates
data.drop_duplicates(inplace=True)

#Remove any rows that contain missing or null values 
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 986 entries, 0 to 999
# Data columns (total 57 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   chroma_stft_mean         986 non-null    float64
#  1   chroma_stft_var          986 non-null    float64
#  2   rms_mean                 986 non-null    float64
#  3   rms_var                  986 non-null    float64
#  4   spectral_centroid_mean   986 non-null    float64
#  5   spectral_centroid_var    986 non-null    float64
#  6   spectral_bandwidth_mean  986 non-null    float64
#  7   spectral_bandwidth_var   986 non-null    float64
#  8   rolloff_mean             986 non-null    float64
#  9   rolloff_var              986 non-null    float64
#  10  zero_crossing_rate_mean  986 non-null    float64
#  11  zero_crossing_rate_var   986 non-null    float64
#  12  harmony_mean             986 non-null    float64
# ...

# %%
#Scaling the data
scaler = StandardScaler()

# extract the numerical columns as a numpy array
df = data.select_dtypes(include=[np.number]).values

# scale the array using StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# convert the scaled array back to a dataframe
df_scaled = pd.DataFrame(df_scaled, columns=data.select_dtypes(include=[np.number]).columns)

# display the first few rows of the scaled dataframe
df_scaled.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0         -0.338634         0.312175 -0.007580 -0.053793
# 1         -0.450774         1.119554 -0.529296 -0.182396
# 2         -0.173024        -0.139453  0.682497 -0.076678
# 3          0.329921         0.992263  0.157778  0.943293
# 4         -0.846646         0.193399 -0.596551 -0.202039
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0               -0.573125              -0.847436                -0.450420
# 1               -0.927731              -0.230250                -0.380956
# 2               -0.896129              -0.780486                -0.934076
# 3               -1.570057              -0.710539                -1.221311
# 4               -0.502147              -0.311639                -0.933184
#
#    spectral_bandwidth_var  rolloff_mean  rolloff_var  ...  mfcc16_mean  \
# 0               -0.531103     -0.477893    -0.662022  ...    -0.077722
# ...

# %%
x = df_scaled

x
# Out:
#      chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0           -0.338634         0.312175 -0.007580 -0.053793
# 1           -0.450774         1.119554 -0.529296 -0.182396
# 2           -0.173024        -0.139453  0.682497 -0.076678
# 3            0.329921         0.992263  0.157778  0.943293
# 4           -0.846646         0.193399 -0.596551 -0.202039
# ..                ...              ...       ...       ...
# 981         -0.314498        -0.760603 -0.779835 -0.756790
# 982          0.255393        -1.461314 -0.825912 -0.687939
# 983          0.664309        -1.437590 -0.746882 -0.763253
# 984         -0.187112         0.668788 -0.713264 -0.511501
# 985         -0.237022        -0.060462 -1.160798 -0.759417
#
#      spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                 -0.573125              -0.847436                -0.450420
# 1                 -0.927731              -0.230250                -0.380956
# ...
