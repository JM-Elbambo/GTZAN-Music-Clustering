# %%
import pandas as pd

# Import dataset
df = pd.read_csv("dataset/dataset.csv")
df.describe()
# Out:
#        chroma_stft_mean  chroma_stft_var     rms_mean      rms_var  \
# count       1000.000000      1000.000000  1000.000000  1000.000000
# mean           0.378682         0.086340     0.130930     0.003051
# std            0.081705         0.007735     0.065683     0.003634
# min            0.171939         0.044555     0.005276     0.000004
# 25%            0.319562         0.082298     0.086657     0.000942
# 50%            0.383148         0.086615     0.122443     0.001816
# 75%            0.435942         0.091256     0.175682     0.003577
# max            0.663685         0.108111     0.397973     0.027679
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             1000.000000           1.000000e+03              1000.000000
# mean              2201.780898           4.696916e+05              2242.541070
# std                715.960600           4.008995e+05               526.316473
# min                570.040355           7.911251e+03               898.066208
# 25%               1627.697312           1.843505e+05              1907.240605
# 50%               2209.263090           3.384862e+05              2221.392843
# 75%               2691.294667           6.121479e+05              2578.469836
# max               4435.243901           3.036843e+06              3509.646417
#
#        spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_mean  \
# count             1000.000000   1000.000000  1.000000e+03  ...  1000.000000
# mean            137079.155166   4571.549304  1.844345e+06  ...     1.148144
# std              96455.666325   1574.791602  1.425085e+06  ...     4.578948
# min              10787.185060    749.140636  1.468612e+04  ...   -15.693844
# 25%              67376.554430   3380.069642  7.727312e+05  ...    -1.863280
# 50%             111977.548050   4658.524473  1.476115e+06  ...     1.212809
# 75%             182371.576800   5533.810460  2.555262e+06  ...     4.359662
# max             694784.811500   8677.672688  8.660900e+06  ...    13.457150
#
#         mfcc16_var  mfcc17_mean   mfcc17_var  mfcc18_mean   mfcc18_var  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     60.730958    -3.966028    62.633624     0.507696    63.712586
# std      33.781951     4.549697    33.479172     3.869105    34.401977
# min       9.169314   -17.234728    13.931521   -11.963694    15.420555
# 25%      40.376442    -7.207225    40.830875    -2.007015    41.884240
# 50%      52.325077    -4.065605    54.717674     0.669643    54.804890
# 75%      71.691755    -0.838737    75.040838     3.119212    75.385832
# max     392.932373    11.482946   406.058868    15.388390   332.905426
#
#        mfcc19_mean   mfcc19_var  mfcc20_mean   mfcc20_var
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -2.328761    66.231930    -1.095348    70.126096
# std       3.755957    37.174631     3.837007    45.228512
# min     -18.501955    13.487622   -19.929634     7.956583
# 25%      -4.662925    41.710184    -3.368996    42.372865
# 50%      -2.393862    57.423059    -1.166289    59.186117
# 75%       0.150573    78.626444     1.312615    85.375374
# max      14.694924   393.161987    15.369627   506.065155
#
# [8 rows x 57 columns]

# %%
df.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.350088         0.088757  0.130228  0.002827
# 1          0.340914         0.094980  0.095948  0.002373
# 2          0.363637         0.085275  0.175570  0.002746
# 3          0.404785         0.093999  0.141093  0.006346
# 4          0.308526         0.087841  0.091529  0.002303
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1784.165850            129774.0645              2002.449060
# 1             1530.176679            375850.0736              2039.036516
# 2             1552.811865            156467.6434              1747.702312
# 3             1070.106615            184355.9424              1596.412872
# 4             1835.004266            343399.9393              1748.172116
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_mean  \
# 0             85882.76132   3805.839606  9.015054e+05  ...     0.752740
# 1            213843.75550   3550.522098  2.977893e+06  ...     0.927998
# 2             76254.19226   3042.260232  7.840345e+05  ...     2.451690
# 3            166441.49480   2184.745799  1.493194e+06  ...     0.780874
# 4             88445.20904   3579.757627  1.572978e+06  ...    -4.520576
#
#    mfcc16_var  mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0   52.420910    -1.690215   36.524071    -0.408979   41.597103    -2.303523
# 1   55.356403    -0.731125   60.314529     0.295073   48.120598    -0.283518
# 2   40.598766    -7.729093   47.639427    -1.816407   52.382141    -3.439720
# 3   44.427753    -3.319597   50.206673     0.636965   37.319130    -0.619121
# 4   86.099236    -5.454034   75.269707    -0.916874   53.613918    -4.404827
#
#    mfcc19_var  mfcc20_mean  mfcc20_var
# 0   55.062923     1.221291   46.936035
# 1   51.106190     0.531217   45.786282
# 2   46.639660    -2.231258   30.573025
# 3   37.259739    -3.407448   31.949339
# 4   62.910812   -11.703234   55.195160
#
# [5 rows x 57 columns]

# %% [markdown]
# <h1>Data Preprocessing</h1>

# %%
print("Shape")
print("Before dropping:", df.shape)

# Remove duplicates
df.drop_duplicates(inplace=True)

# Remove any rows that contain missing or null values 
df.dropna(inplace=True)

print("After dropping:", df.shape)
# Out:
# Shape
# Before dropping: (1000, 57)
# After dropping: (986, 57)

# %%
from sklearn.preprocessing import StandardScaler

# Scaling the data
scaler = StandardScaler()
ndarray_scaled = scaler.fit_transform(df)

# Convert the scaled array back to a dataframe
df_scaled = pd.DataFrame(ndarray_scaled)

# Display the first few rows of the scaled dataframe
df_scaled.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.338634  0.312175 -0.007580 -0.053793 -0.573125 -0.847436 -0.450420
# 1 -0.450774  1.119554 -0.529296 -0.182396 -0.927731 -0.230250 -0.380956
# 2 -0.173024 -0.139453  0.682497 -0.076678 -0.896129 -0.780486 -0.934076
# 3  0.329921  0.992263  0.157778  0.943293 -1.570057 -0.710539 -1.221311
# 4 -0.846646  0.193399 -0.596551 -0.202039 -0.502147 -0.311639 -0.933184
#
#          7         8         9   ...        47        48        49        50  \
# 0 -0.531103 -0.477893 -0.662022  ... -0.077722 -0.245002  0.494448 -0.775704
# 1  0.795296 -0.639845  0.799818  ... -0.039327 -0.158354  0.705762 -0.066446
# 2 -0.630909 -0.962244 -0.744726  ...  0.294477 -0.593959 -0.836079 -0.444325
# 3  0.303941 -1.506180 -0.245455  ... -0.071559 -0.480938  0.135452 -0.367788
# 4 -0.504541 -0.621301 -0.189285  ... -1.232980  0.749089 -0.334822  0.379408
#
#          51        52        53        54        55        56
# 0 -0.229200 -0.641853 -0.004534 -0.301468  0.605120 -0.514789
# 1 -0.047361 -0.452832  0.539509 -0.407503  0.425698 -0.540108
# 2 -0.592702 -0.329351 -0.310544 -0.527200 -0.292554 -0.875127
# 3  0.040941 -0.765810  0.449122 -0.778568 -0.598367 -0.844818
# 4 -0.360376 -0.293660 -0.570474 -0.091156 -2.755298 -0.332911
#
# [5 rows x 57 columns]
